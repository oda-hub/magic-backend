# %%
import pprint as pp

# %% [markdown]
# ## Client Setup

# %%
from magic_data_server.client_api import MagicClientAPI
client=MagicClientAPI(port=5001)

# %% [markdown]
# ## Accessing products

# %%
p_ids=client.get_paper_ids()
# Out:
# request http://0.0.0.0:5001/api/v1.0/magic/paper_ids None
# <Response [200]>

# %%
print(p_ids)
# Out:
# ['19a', '19e']

# %%
catalog=client.get_catalog(paper_id='19e')
# Out:
# request http://0.0.0.0:5001/api/v1.0/magic/catalog {'paper_id': '19e'}
# <Response [200]>

# %%
pp.pprint(catalog)
# Out:
# {'Comments': None,
#  'File list MAGIC': ['magic_19e_sed_fig1_target_all.ecsv',
#                      'magic_19e_sed_fig1_target01.ecsv',
#                      'magic_19e_sed_fig1_target04.ecsv',
#                      'magic_19e_sed_fig1_target07.ecsv',
#                      'magic_19e_sed_fig1_target08.ecsv',
#                      'magic_19e_sed_fig1_target09.ecsv'],
#  'File list MWL': ['magic_19e_lc1_fig2_target_all.ecsv',
#                    'magic_19e_lc1_fig2_target01.ecsv',
#                    'magic_19e_lc1_fig2_target02.ecsv',
#                    'magic_19e_lc1_fig2_target03.ecsv',
#                    'magic_19e_lc1_fig2_target04.ecsv',
#                    'magic_19e_lc1_fig2_target05.ecsv',
#                    'magic_19e_lc1_fig2_target06.ecsv',
#                    'magic_19e_lc1_fig2_target07.ecsv',
#                    'magic_19e_lc1_fig2_target08.ecsv',
#                    'magic_19e_lc1_fig2_target09.ecsv',
# ...

# %%
targets_dict=client.get_targets(paper_id='19e')
pp.pprint(targets_dict)
# Out:
# request http://0.0.0.0:5001/api/v1.0/magic/targets {'paper_id': '19e'}
# <Response [200]>
# {'src_00': ['TXS0210+515',
#             'BZBJ0214+5144',
#             ' 1RXSJ021417.8+514457',
#             ' 87GB02109+5130',
#             ' GB6J0214+5145',
#             ' 5BZGJ0214+5144',
#             ' GB6B0210+5131',
#             ' 2WHSPJ021417.8+514451',
#             ' 2FHLJ0214.9+5149'],
#  'src_01': ['TXS0637-128'],
#  'src_02': ['BZBJ0809+3455'],
#  'src_03': ['RBS0723'],
#  'src_04': ['1ES0927+500'],
#  'src_05': ['RBS0921'],
#  'src_06': ['1ES1426+428'],
#  'src_07': ['1ES2037+521'],
#  'src_08': ['RGBJ2042+244'],
#  'src_09': ['RGBJ2323+147'],
#  'src_10': ['1ES0229+200']}

# %%
files_dict=client.search_by_name('TXS0210+515',paper_id='19e')
pp.pprint(files_dict)
# Out:
# request http://0.0.0.0:5001/api/v1.0/magic/search-by-name {'target_name': 'TXS0210+515', 'paper_id': '19e'}
# <Response [200]>
# {'MAGIC_files': ['magic_19e_sed_fig1_target01.ecsv'],
#  'MWL_files': ['magic_19e_lc1_fig2_target01.ecsv',
#                'magic_19e_lc1_fig2_target010.ecsv',
#                'magic_19e_lc1_fig2_target011.ecsv',
#                'magic_19e_sed_fig3_mwl_target01.ecsv',
#                'magic_19e_sed_fig3_nofit_target01.ecsv']}

# %%
sed_table=client.get_table_data(file_name='magic_19e_sed_fig3_mwl_target01.ecsv',paper_id='19e')
# Out:
# request http://0.0.0.0:5001/api/v1.0/magic/get-table {'file_name': 'magic_19e_sed_fig3_mwl_target01.ecsv', 'paper_id': '19e'}
# <Response [200]>

# %%
sed_table
# Out:
# <Table length=47>
#        freq          freq_elo    freq_eup  ...  tstop   texpo      comments
#       1 / s           1 / s       1 / s    ...   mjd      s         latex
#      float32         float32     float32   ... float32 float32      str13
# ------------------ ----------- ----------- ... ------- -------- -------------
#  555000000000000.0         0.0         0.0 ... 57417.0      nan          UVOT
#  692500000000000.0         0.0         0.0 ... 57417.0      nan          UVOT
#  856300000000000.0         0.0         0.0 ... 57417.0      nan          UVOT
# 1157000000000000.0         0.0         0.0 ... 57417.0      nan          UVOT
# 1345000000000000.0         0.0         0.0 ... 57417.0      nan          UVOT
# 1475000000000000.0         0.0         0.0 ... 57417.0      nan          UVOT
#           2.08e+17    1.93e+16    1.93e+16 ... 57417.0      nan           XRT
#           2.45e+17    1.81e+16    1.81e+16 ... 57417.0      nan           XRT
# ...

# %%
sed_table['nufnu'].to('GeV/(cm2 s)')
# Out:
# <Quantity [8.4315452e-09, 5.3255622e-09, 2.9031388e-09, 1.7755967e-09,
#            1.7119475e-09, 1.5010271e-09, 2.1845281e-09, 2.2219770e-09,
#            2.3405657e-09, 2.4341884e-09, 2.9459921e-09, 2.9647167e-09,
#            2.9647167e-09, 3.1706864e-09, 3.2018941e-09, 3.2518261e-09,
#            3.3766563e-09, 3.4515544e-09, 3.6387997e-09, 3.3704146e-09,
#            3.3204828e-09, 3.5264525e-09, 3.7573882e-09, 3.4016221e-09,
#            3.5514185e-09, 3.8198031e-09, 3.5014864e-09, 3.8822185e-09,
#            3.1582035e-09, 3.5451768e-09, 3.7261807e-09, 3.6887315e-09,
#            3.6824903e-09, 3.2892753e-09, 3.8073202e-09, 3.5014864e-09,
#            3.4640375e-09, 3.6387997e-09, 3.3641734e-09, 3.3142411e-09,
#            6.2040600e-10, 7.0529049e-10, 1.7788300e-09, 6.1853354e-09,
#            4.2379844e-10, 5.7858790e-10, 7.9891310e-10] GeV / (cm2 s)>

# %%
sed_table_no_fit=client.get_table_data(file_name='magic_19e_sed_fig3_mwl_target01.ecsv',paper_id='19e')
# Out:
# request http://0.0.0.0:5001/api/v1.0/magic/get-table {'file_name': 'magic_19e_sed_fig3_mwl_target01.ecsv', 'paper_id': '19e'}
# <Response [200]>

# %%
from magic_data_server.plot_tools import DataPlot

# %%
# %matplotlib notebook

sed_plot=DataPlot()
sed_plot.add_sed(sed_table)
sed_plot.ax.set_ylim(5E-14,1E-9)
sed_plot.ax.grid()
# Out:
# <img src="data:image/png;base64,..." width="798.8889100522176">

# %%
client.search_by_name('1ES0229+200',paper_id='19e')
# Out:
# request http://0.0.0.0:5001/api/v1.0/magic/search-by-name {'target_name': '1ES0229+200', 'paper_id': '19e'}
# <Response [200]>
# {'MWL_files': ['magic_19e_sed_fig3_mwl_target11.ecsv',
#   'magic_19e_sed_fig3_nofit_target11.ecsv'],
#  'MAGIC_files': []}

# %%
lc_table=client.get_table_data(file_name='magic_19e_lc1_fig2_target11.ecsv',paper_id='19e')
# Out:
# request http://0.0.0.0:5001/api/v1.0/magic/get-table {'file_name': 'magic_19e_lc1_fig2_target11.ecsv', 'paper_id': '19e'}
# <Response [200]>

# %%
lc_table
# Out:
# <Table length=67>
#     nufnu       nufnu_elo     nufnu_eup   ...  tstop   texpo      comments
# erg / (cm2 s) erg / (cm2 s) erg / (cm2 s) ...   mjd      s         latex
#    float32       float32       float32    ... float32 float32      str15
# ------------- ------------- ------------- ... ------- ------- ---------------
#     1.327e-11    3.4724e-12    3.4724e-12 ...     nan   339.6 photon counting
#    1.2247e-11    6.2596e-13    6.2596e-13 ...     nan  3259.0 photon counting
#    8.7033e-12     7.135e-13     7.135e-13 ...     nan  3366.4 photon counting
#    2.2589e-11    3.2199e-12    3.2199e-12 ...     nan   394.9 photon counting
#    1.6561e-11    1.1168e-12    1.1168e-12 ...     nan  2356.8 photon counting
#    2.8109e-11    1.3701e-12    1.3701e-12 ...     nan  5209.4 photon counting
#     2.886e-11    3.9598e-12    3.9598e-12 ...     nan   539.4 photon counting
#    1.8271e-11    9.6144e-13    9.6144e-13 ...     nan  5331.7 photon counting
# ...

# %%
lc_table['nufnu'].to('GeV/(cm2 s)')
# Out:
# <Quantity [8.28248226e-09, 7.64397612e-09, 5.43217249e-09, 1.40989442e-08,
#            1.03365636e-08, 1.75442576e-08, 1.80129938e-08, 1.14038601e-08,
#            6.25399155e-09, 5.21109822e-09, 5.37131761e-09, 6.49928333e-09,
#            8.88790819e-09, 6.20000273e-09, 6.91683999e-09, 5.48678525e-09,
#            4.08656575e-09, 9.37162525e-09, 5.05736963e-09, 5.98972649e-09,
#            7.26636440e-09, 6.04527584e-09, 3.16026316e-09, 4.53426896e-09,
#            4.35139258e-09, 5.13769782e-09, 3.43126949e-09, 4.23149338e-09,
#            8.55710880e-09, 5.87282267e-09, 9.22058163e-09, 8.76869599e-09,
#            1.08876872e-08, 7.82310661e-09, 1.29636142e-08, 7.36310790e-09,
#            9.74049907e-09, 9.60256141e-09, 1.06686118e-08, 8.29246893e-09,
#            9.24929200e-09, 7.73322917e-09, 9.93835503e-09, 8.20883272e-09,
#            8.82923867e-09, 8.15702794e-09, 8.80177531e-09, 7.03230807e-09,
# ...

# %%
# %matplotlib notebook

lc_plot=DataPlot()
lc_plot.add_lc(lc_table)
lc_plot.ax.grid()
# Out:
# <img src="data:image/png;base64,..." width="798.8889100522176">

# %% [markdown]
# ## Error communication

# %% [markdown]
# The cells below show how error communication works.

# %%
#missing file error communication

lc_table=client.get_table_data(file_name='magic_19e_lc1_fig2_targetX.ecsv',paper_id='19e')
# Out:
# request http://0.0.0.0:5001/api/v1.0/magic/get-table {'file_name': 'magic_19e_lc1_fig2_targetX.ecsv', 'paper_id': '19e'}
# <Response [410]>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: RemoteException (line 40): error on remote server: table file is empty/corrupted or missing: [Errno 2] No such file or directory: 'MAGIC_data/data/19e/magic_19e_lc1_fig2_targetX.ecsv'
# /Users/orion/anaconda3/envs/magic-backend/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3327: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
#worngly formatted file error communication

lc_table=client.get_table_data(file_name='magic_19e_lc1_fig2_target010.ecsv',paper_id='19e')
# Out:
# request http://0.0.0.0:5001/api/v1.0/magic/get-table {'file_name': 'magic_19e_lc1_fig2_target010.ecsv', 'paper_id': '19e'}
# <Response [410]>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: RemoteException (line 40): error on remote server: table file is empty/corrupted or missing:
# ERROR: Unable to guess table format with the guesses listed below:
# Reader:Ecsv fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:FixedWidthTwoLine fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:RST fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:FastBasic fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:Basic fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# Reader:FastRdb fast_reader: {'enable': True} fill_values: [('', '0')] strict_names: True
# ...
